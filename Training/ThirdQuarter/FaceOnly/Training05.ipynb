# %% [markdown]
# # Training5
#
# In this notebook file, ThirdQuarter-FaceOnly dataset will be read from pkl file.
#
# Input(X) and Output(Y) numpy arrays will be created from pandas dataframes.
#
# VGG16 pre-trained model will be load and used.
#
# The pre-trained model will be set to non-trainable and will only be used for feature extraction.
#
# Training will only be performed on the fully connected layers and the output layer, that will be added to the end of the pre-trained model.
#
# In this way, the experience gained by the model on very large data sets will be used for this classification problem.
#
# This method is known as [**Transfer Learning**](https://en.wikipedia.org/wiki/Transfer_learning "wikipedia").
#
# A keras utils Sequence class will be defined so that operations can be performed on the data to be used during the training.
#
# Performance will be checked with Validation data while training model with Training data.
#
# Accuracy and Loss charts will be drawn according to epoch numbers.
#
# The results obtained by evaluating the model with Test data will be printed.

# %%
#Libraries are being imported
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt

# %%
#Library versions are being printed
print('numpy Version: ' + np.__version__)
print('pandas Version: ' + pd.__version__)
print('tensorflow Version: ' + tf.__version__)
print('matplotlib Version: ' + matplotlib.__version__)
# Out:
# numpy Version: 1.22.3
# pandas Version: 1.4.3
# tensorflow Version: 2.6.0
# matplotlib Version: 3.5.2

# %%
#GPU will be used for training
myGPU = tf.test.gpu_device_name()
if myGPU:
    print(myGPU)
else:
    print("Error")
# Out:
# /device:GPU:0

# %%
#Person dataframe in ThirdQuarter is being read from md5 file
personDf = pd.read_pickle("../../../Data/ThirdQuarter/Person.pkl")
personDf
# Out:
#                          Name
# ID
# 0                Adrien Brody
# 1             Anna Kournikova
# 2                 Ann Veneman
# 3               Ari Fleischer
# 4                Bill McBride
# 5        Catherine Zeta-Jones
# 6               Charles Moose
# 7            Condoleezza Rice
# 8              Edmund Stoiber
# 9              George HW Bush
# 10  Gonzalo Sanchez de Lozada
# 11               Gordon Brown
# 12              Harrison Ford
# 13                Howard Dean
# 14                 Ian Thorpe
# 15                Jackie Chan
# 16              Jacques Rogge
# 17                James Kelly
# 18                 Jason Kidd
# 19              Javier Solana
# 20         Jean-David Levitte
# 21                   Jeb Bush
# 22            Jennifer Garner
# 23                 Jiri Novak
# 24              Joe Lieberman
# 25        John Allen Muhammad
# 26               John Paul II
# 27               Keanu Reeves
# 28             Kim Ryong-sung
# 29            Lucio Gutierrez
# 30         Mark Philippoussis
# 31            Michael Jackson
# 32                  Mike Weir
# 33           Mohammad Khatami
# 34               Muhammad Ali
# 35      Nicanor Duarte Frutos
# 36        Paradorn Srichaphan
# 37               Paul Burrell
# 38             Paul Wolfowitz
# 39         Queen Elizabeth II
# 40           Richard Gephardt
# 41               Richard Gere
# 42         Rubens Barrichello
# 43                Salma Hayek
# 44              Sergey Lavrov
# 45     Sergio Vieira De Mello
# 46               Tang Jiaxuan
# 47             Tommy Thompson
# 48                 Tom Cruise
# 49                  Tom Hanks
# 50             Walter Mondale
# 51                 Wen Jiabao

# %%
#FaceOnly Training data is being read from md5 file
trainingDf = pd.read_pickle("../../../Data/ThirdQuarter/FaceOnly/Training.pkl")
trainingDf
# Out:
#      PersonID                                           ImageBGR DetectionType
# 0           1  [[[71, 116, 99], [69, 116, 98], [67, 115, 98],...    SingleFace
# 1          18  [[[28, 64, 102], [29, 65, 102], [33, 66, 102],...    SingleFace
# 2          38  [[[97, 85, 85], [96, 83, 83], [93, 80, 80], [9...    SingleFace
# 3          50  [[[179, 108, 98], [180, 107, 98], [181, 107, 9...    SingleFace
# 4          48  [[[18, 32, 44], [18, 32, 44], [17, 33, 45], [1...    SingleFace
# ..        ...                                                ...           ...
# 407        41  [[[142, 177, 187], [141, 175, 184], [140, 170,...    SingleFace
# 408         3  [[[22, 43, 58], [19, 41, 57], [13, 37, 56], [1...    SingleFace
# 409        34  [[[126, 111, 18], [126, 111, 18], [127, 111, 1...    SingleFace
# 410        14  [[[243, 246, 244], [237, 240, 238], [226, 229,...    SingleFace
# 411        10  [[[48, 56, 49], [48, 56, 49], [47, 55, 48], [4...    SingleFace
#
# [412 rows x 3 columns]

# %%
#trainingX is being extracted from trainingDf as wanted shape
#trainingX contains images with pixel values of data type np.uint8 in the range [0, 255]

#Many pre-trained models, including the ones to be used within the scope of this project,
#have been trained with images containing pixel values in the [-1, 1] range
#In this way, the data will be symmetrical and the performance of the Backpropagation algorithm will be increased
#See https://en.wikipedia.org/wiki/Backpropagation
#See also https://stackoverflow.com/questions/59540276/why-in-preprocessing-image-data-we-need-to-do-zero-centered-data
#Therefore, training will be performed by converting pixel values to this range with the simplest method (pixel / 127.5 - 1)

trainingX = (np.array(trainingDf.ImageBGR.values.tolist()) / 127.5) - 1
trainingX.shape
# Out:
# (412, 224, 224, 3)

# %%
#trainingY is being extracted from trainingDf as wanted shape
trainingY = np.array(trainingDf.PersonID.values.tolist()).reshape((-1,1))
trainingY.shape
# Out:
# (412, 1)

# %%
#FaceOnly Validation data is being read from md5 file
validationDf = pd.read_pickle("../../../Data/ThirdQuarter/FaceOnly/Validation.pkl")
validationDf
# Out:
#     PersonID                                           ImageBGR DetectionType
# 0         32  [[[49, 96, 80], [49, 95, 79], [48, 94, 78], [4...    SingleFace
# 1         13  [[[152, 102, 96], [151, 101, 95], [149, 99, 93...    SingleFace
# 2         20  [[[14, 31, 50], [13, 31, 50], [13, 30, 51], [1...    SingleFace
# 3         36  [[[7, 13, 8], [6, 12, 7], [5, 10, 4], [5, 8, 3...    SingleFace
# 4         41  [[[185, 204, 207], [185, 204, 207], [185, 204,...    SingleFace
# ..       ...                                                ...           ...
# 91        28  [[[0, 7, 2], [0, 7, 3], [1, 7, 5], [3, 8, 8], ...  MultipleFace
# 92         6  [[[36, 43, 58], [38, 45, 60], [41, 48, 63], [4...  MultipleFace
# 93         9  [[[62, 60, 66], [64, 61, 69], [67, 63, 74], [7...    SingleFace
# 94        39  [[[11, 13, 67], [10, 12, 63], [9, 9, 54], [7, ...    SingleFace
# 95        24  [[[35, 17, 10], [35, 17, 11], [36, 17, 12], [3...    SingleFace
#
# [96 rows x 3 columns]

# %%
#validationX is being extracted from validationDf as wanted shape
#validationX contains images with pixel values of data type np.uint8 in the range [0, 255]

#Many pre-trained models, including the ones to be used within the scope of this project,
#have been trained with images containing pixel values in the [-1, 1] range
#In this way, the data will be symmetrical and the performance of the Backpropagation algorithm will be increased
#See https://en.wikipedia.org/wiki/Backpropagation
#See also https://stackoverflow.com/questions/59540276/why-in-preprocessing-image-data-we-need-to-do-zero-centered-data
#Therefore, training will be performed by converting pixel values to this range with the simplest method (pixel / 127.5 - 1)

validationX = (np.array(validationDf.ImageBGR.values.tolist()) / 127.5) - 1
validationX.shape
# Out:
# (96, 224, 224, 3)

# %%
#validationY is being extracted from validationDf as wanted shape
validationY = np.array(validationDf.PersonID.values.tolist()).reshape((-1,1))
validationY.shape
# Out:
# (96, 1)

# %%
#VGG16 pre-trained model is being loaded
#The original VGG16 model was trained with images with size of (224, 224, 3) 
#in BGR color order and pixel values of [-1, 1] (zero centered) as default
#See https://keras.io/api/applications/vgg/ for more information
#Since images of dataset saved as size of (224, 224, 3) in BGR color order and pixel values of [0, 255]
#Pixel values were converted to [-1, 1] range while preparing trainingX and validationX

#Model is set to non-trainable
#In this way, the convolutional layers that will be used for feature extraction will be used without changing them
#Fully connected layers will be fed the feature-map obtained from the pre-trained convolutional model
#the training process will be performed on this fully connected layers

model = tf.keras.applications.vgg16.VGG16(include_top = False, input_shape = ((224, 224, 3)))
model.trainable = False
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#The pre-trained model is being connected to the fully connected layer where the training will performed
#A dropout layer is being added to the the model to prevent overfitting,
#and the model is being completed with the addition of the output layer
model = tf.keras.models.Sequential([
    model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(2048, activation = 'relu'),
    tf.keras.layers.Dense(2048, activation = 'relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(personDf.shape[0], activation = tf.nn.softmax)
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              51382272
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 52)                106548
# =================================================================
# Total params: 70,399,860
# Trainable params: 55,685,172
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#Model is being compiled with Adam optimizer
#Adam optimizer is a common used optimizer
#See https://keras.io/api/optimizers/adam/
#See also https://towardsdatascience.com/7-tips-to-choose-the-best-optimizer-47bb9c1219e
#SparseCategoricalCrossentropy loss function is being used because of the label format of the data
#SparseCategoricalAccuracy is being used as metric because of the label format of the data
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name = 'accuracy')]
)

# %%
#A class inherited from keras utils Sequence is being created
class FitSequence(tf.keras.utils.Sequence):
    
    #Constructor method is being defined
    def __init__(self, image, label, batchSize):
        self.image, self.label = image, label
        self.batchSize = batchSize
        
        #A numpy array for image indexes is being created
        #This array will be used to shuffle the data
        self.index = np.arange(self.image.shape[0])
    
    #__len__ method is being defined
    #This method will be used by the model to show the amount of progress of each epoch
    def __len__(self):
        return int(np.ceil(self.image.shape[0] / float(self.batchSize)))
    
    #__getitem__ method is being defined
    #The model will retrieve the batches it will use during training by calling this method
    #With this method, the data to be used by the model can be manipulated
    def __getitem__(self, idx):
        
        #When the model requests data, the next batch size will be selected based on index array
        indexPart = self.index[idx * self.batchSize : (idx + 1) * self.batchSize]
        
        batchX = self.image[indexPart]
        batchY = self.label[indexPart]
        return np.array(batchX), np.array(batchY)
    
    #on_epoch_end method is being defined
    #The model will call this method after each epoch is ended
    def on_epoch_end(self):
        
        #At the end of the epoch, the index array is being shuffled 
        #so that the data in the next epoch is returned in different orders
        np.random.shuffle(self.index)

# %%
#model is being trained with 50 epochs and 16 batchSize using GPU
#A small batchSize value is being chosen to prevent GPU memory problem
#Large batchSize reduce training time while also generally providing better results
with tf.device(myGPU):
    trainingHistory = model.fit(
        FitSequence(trainingX, trainingY, 16),
        epochs = 50,
        validation_data = FitSequence(validationX, validationY, 16)
    )
# Out:
# Epoch 1/50
# 26/26 [==============================] - 40s 1s/step - loss: 6.4578 - accuracy: 0.0388 - val_loss: 3.8520 - val_accuracy: 0.0521
# Epoch 2/50
# 26/26 [==============================] - 17s 652ms/step - loss: 3.6090 - accuracy: 0.0995 - val_loss: 3.4120 - val_accuracy: 0.2083
# Epoch 3/50
# 26/26 [==============================] - 17s 654ms/step - loss: 2.5427 - accuracy: 0.3350 - val_loss: 2.6145 - val_accuracy: 0.2812
# Epoch 4/50
# 26/26 [==============================] - 17s 655ms/step - loss: 1.2228 - accuracy: 0.6626 - val_loss: 2.2319 - val_accuracy: 0.3438
# Epoch 5/50
# 26/26 [==============================] - 17s 664ms/step - loss: 0.3180 - accuracy: 0.9320 - val_loss: 1.9988 - val_accuracy: 0.4896
# Epoch 6/50
# 26/26 [==============================] - 17s 665ms/step - loss: 0.1276 - accuracy: 0.9684 - val_loss: 1.8581 - val_accuracy: 0.4583
# Epoch 7/50
# 26/26 [==============================] - 17s 673ms/step - loss: 0.0842 - accuracy: 0.9854 - val_loss: 2.1639 - val_accuracy: 0.3958
# Epoch 8/50
# 26/26 [==============================] - 18s 683ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 1.6500 - val_accuracy: 0.5312
# Epoch 9/50
# 26/26 [==============================] - 17s 672ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7226 - val_accuracy: 0.5312
# Epoch 10/50
# 26/26 [==============================] - 18s 679ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.5808 - val_accuracy: 0.5417
# Epoch 11/50
# 26/26 [==============================] - 18s 690ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.5633 - val_accuracy: 0.5521
# Epoch 12/50
# 26/26 [==============================] - 18s 696ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.5627 - val_accuracy: 0.5729
# Epoch 13/50
# 26/26 [==============================] - 18s 700ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.5797 - val_accuracy: 0.5833
# Epoch 14/50
# 26/26 [==============================] - 18s 692ms/step - loss: 9.0656e-04 - accuracy: 1.0000 - val_loss: 1.5498 - val_accuracy: 0.5938
# Epoch 15/50
# 26/26 [==============================] - 18s 687ms/step - loss: 7.1311e-04 - accuracy: 1.0000 - val_loss: 1.5428 - val_accuracy: 0.5938
# Epoch 16/50
# 26/26 [==============================] - 18s 687ms/step - loss: 6.5317e-04 - accuracy: 1.0000 - val_loss: 1.5346 - val_accuracy: 0.6042
# Epoch 17/50
# 26/26 [==============================] - 18s 688ms/step - loss: 5.8831e-04 - accuracy: 1.0000 - val_loss: 1.5400 - val_accuracy: 0.6042
# Epoch 18/50
# 26/26 [==============================] - 18s 687ms/step - loss: 5.3101e-04 - accuracy: 1.0000 - val_loss: 1.5373 - val_accuracy: 0.6146
# Epoch 19/50
# 26/26 [==============================] - 18s 690ms/step - loss: 5.3171e-04 - accuracy: 1.0000 - val_loss: 1.5311 - val_accuracy: 0.6042
# Epoch 20/50
# 26/26 [==============================] - 19s 730ms/step - loss: 5.4810e-04 - accuracy: 1.0000 - val_loss: 1.5410 - val_accuracy: 0.5938
# Epoch 21/50
# 26/26 [==============================] - 25s 977ms/step - loss: 4.4797e-04 - accuracy: 1.0000 - val_loss: 1.5515 - val_accuracy: 0.6042
# Epoch 22/50
# 26/26 [==============================] - 24s 946ms/step - loss: 4.1107e-04 - accuracy: 1.0000 - val_loss: 1.5328 - val_accuracy: 0.5938
# Epoch 23/50
# 26/26 [==============================] - 21s 804ms/step - loss: 3.8533e-04 - accuracy: 1.0000 - val_loss: 1.5101 - val_accuracy: 0.5833
# Epoch 24/50
# 26/26 [==============================] - 21s 806ms/step - loss: 3.7232e-04 - accuracy: 1.0000 - val_loss: 1.5502 - val_accuracy: 0.5938
# Epoch 25/50
# 26/26 [==============================] - 21s 806ms/step - loss: 3.8049e-04 - accuracy: 1.0000 - val_loss: 1.5327 - val_accuracy: 0.6146
# Epoch 26/50
# 26/26 [==============================] - 21s 807ms/step - loss: 3.1310e-04 - accuracy: 1.0000 - val_loss: 1.5136 - val_accuracy: 0.6042
# Epoch 27/50
# 26/26 [==============================] - 21s 805ms/step - loss: 3.4928e-04 - accuracy: 1.0000 - val_loss: 1.5168 - val_accuracy: 0.6146
# Epoch 28/50
# 26/26 [==============================] - 21s 805ms/step - loss: 2.6953e-04 - accuracy: 1.0000 - val_loss: 1.5265 - val_accuracy: 0.6146
# Epoch 29/50
# 26/26 [==============================] - 21s 806ms/step - loss: 2.7417e-04 - accuracy: 1.0000 - val_loss: 1.5283 - val_accuracy: 0.5938
# Epoch 30/50
# 26/26 [==============================] - 21s 804ms/step - loss: 2.4559e-04 - accuracy: 1.0000 - val_loss: 1.5183 - val_accuracy: 0.5938
# Epoch 31/50
# 26/26 [==============================] - 21s 804ms/step - loss: 2.3811e-04 - accuracy: 1.0000 - val_loss: 1.5215 - val_accuracy: 0.6042
# Epoch 32/50
# 26/26 [==============================] - 21s 804ms/step - loss: 2.2616e-04 - accuracy: 1.0000 - val_loss: 1.5204 - val_accuracy: 0.5938
# Epoch 33/50
# 26/26 [==============================] - 21s 805ms/step - loss: 2.0309e-04 - accuracy: 1.0000 - val_loss: 1.5205 - val_accuracy: 0.5938
# Epoch 34/50
# 26/26 [==============================] - 20s 761ms/step - loss: 1.7145e-04 - accuracy: 1.0000 - val_loss: 1.5148 - val_accuracy: 0.6042
# Epoch 35/50
# 26/26 [==============================] - 17s 673ms/step - loss: 2.0819e-04 - accuracy: 1.0000 - val_loss: 1.5257 - val_accuracy: 0.5938
# Epoch 36/50
# 26/26 [==============================] - 17s 666ms/step - loss: 1.6287e-04 - accuracy: 1.0000 - val_loss: 1.5163 - val_accuracy: 0.5938
# Epoch 37/50
# 26/26 [==============================] - 17s 665ms/step - loss: 1.8153e-04 - accuracy: 1.0000 - val_loss: 1.5201 - val_accuracy: 0.6042
# Epoch 38/50
# 26/26 [==============================] - 17s 666ms/step - loss: 1.5832e-04 - accuracy: 1.0000 - val_loss: 1.5187 - val_accuracy: 0.6042
# Epoch 39/50
# 26/26 [==============================] - 17s 669ms/step - loss: 1.7015e-04 - accuracy: 1.0000 - val_loss: 1.5305 - val_accuracy: 0.5833
# Epoch 40/50
# 26/26 [==============================] - 18s 679ms/step - loss: 1.2943e-04 - accuracy: 1.0000 - val_loss: 1.5301 - val_accuracy: 0.5938
# Epoch 41/50
# 26/26 [==============================] - 18s 687ms/step - loss: 1.4706e-04 - accuracy: 1.0000 - val_loss: 1.5389 - val_accuracy: 0.5938
# Epoch 42/50
# 26/26 [==============================] - 18s 690ms/step - loss: 1.6074e-04 - accuracy: 1.0000 - val_loss: 1.5404 - val_accuracy: 0.5938
# Epoch 43/50
# 26/26 [==============================] - 18s 688ms/step - loss: 1.4745e-04 - accuracy: 1.0000 - val_loss: 1.5281 - val_accuracy: 0.6042
# Epoch 44/50
# 26/26 [==============================] - 18s 681ms/step - loss: 1.2519e-04 - accuracy: 1.0000 - val_loss: 1.5238 - val_accuracy: 0.6042
# Epoch 45/50
# 26/26 [==============================] - 18s 681ms/step - loss: 1.3684e-04 - accuracy: 1.0000 - val_loss: 1.5200 - val_accuracy: 0.5938
# Epoch 46/50
# 26/26 [==============================] - 18s 687ms/step - loss: 1.2768e-04 - accuracy: 1.0000 - val_loss: 1.5362 - val_accuracy: 0.6042
# Epoch 47/50
# 26/26 [==============================] - 18s 690ms/step - loss: 1.1306e-04 - accuracy: 1.0000 - val_loss: 1.5351 - val_accuracy: 0.6042
# Epoch 48/50
# 26/26 [==============================] - 18s 704ms/step - loss: 1.0974e-04 - accuracy: 1.0000 - val_loss: 1.5361 - val_accuracy: 0.6042
# Epoch 49/50
# 26/26 [==============================] - 18s 707ms/step - loss: 1.1135e-04 - accuracy: 1.0000 - val_loss: 1.5275 - val_accuracy: 0.6146
# Epoch 50/50
# 26/26 [==============================] - 18s 701ms/step - loss: 1.0420e-04 - accuracy: 1.0000 - val_loss: 1.5228 - val_accuracy: 0.6250

# %%
#Loss Chart is being drawn

#Chart Values
plt.plot(trainingHistory.history['loss'])
plt.plot(trainingHistory.history['val_loss'])

#Chart Tittle
plt.title('Model Loss Chart')

#Chart Labels
plt.ylabel('loss')
plt.xlabel('epoch')

#Chart Lines
plt.legend(['Training', 'Validation'], loc='upper left')

#Show Method
plt.show()

# %%
#Loss Chart is being drawn

#Chart Values
plt.plot(trainingHistory.history['accuracy'])
plt.plot(trainingHistory.history['val_accuracy'])

#Chart Tittle
plt.title('model accuracy')

#Chart Labels
plt.ylabel('accuracy')
plt.xlabel('epoch')

#Chart Lines
plt.legend(['Training', 'Validation'], loc='upper left')

#Show Method
plt.show()

# %%
#FaceOnly Test data is being read from md5 file
testDf = pd.read_pickle("../../../Data/ThirdQuarter/FaceOnly/Test.pkl")
testDf
# Out:
#     PersonID                                           ImageBGR DetectionType
# 0          7  [[[9, 11, 22], [9, 11, 23], [10, 12, 25], [11,...    SingleFace
# 1         19  [[[169, 185, 232], [162, 177, 224], [146, 161,...    SingleFace
# 2          1  [[[14, 16, 26], [16, 18, 28], [21, 24, 32], [2...    SingleFace
# 3         50  [[[169, 165, 171], [169, 165, 171], [170, 166,...    SingleFace
# 4          9  [[[25, 25, 125], [26, 26, 127], [29, 29, 131],...    SingleFace
# ..       ...                                                ...           ...
# 76        27  [[[14, 16, 10], [14, 16, 10], [13, 15, 9], [13...    SingleFace
# 77        29  [[[4, 48, 101], [4, 48, 102], [3, 48, 104], [2...    SingleFace
# 78        33  [[[9, 11, 11], [9, 11, 11], [9, 11, 11], [9, 1...    SingleFace
# 79        35  [[[157, 175, 176], [152, 170, 173], [143, 161,...    SingleFace
# 80        37  [[[76, 82, 89], [76, 82, 89], [77, 82, 90], [7...  MultipleFace
#
# [81 rows x 3 columns]

# %%
#testX is being extracted from testDf as wanted shape
#Pixel values are being converted  to the [-1, 1] range with the simplest method (pixel / 127.5 - 1)
testX = (np.array(testDf.ImageBGR.values.tolist()) / 127.5) - 1
testX.shape
# Out:
# (81, 224, 224, 3)

# %%
#testY is being extracted from testDf as wanted shape
testY = np.array(testDf.PersonID.values.tolist()).reshape((-1,1))
testY.shape
# Out:
# (81, 1)

# %%
#Model is being evaluated with test data
#Sequence class is being also used for evaluation to convert test data into the same format as training data
testResult = model.evaluate(FitSequence(testX, testY, 16))
# Out:
# 6/6 [==============================] - 4s 638ms/step - loss: 2.1725 - accuracy: 0.5309

# %%
#Test Loss is being Printed
print('Test Loss: ' + str(testResult[0]))
# Out:
# Test Loss: 2.1724789142608643

# %%
#Test Accuracy is being Printed
print('Test Accuracy: ' + str(testResult[1]))
# Out:
# Test Accuracy: 0.5308641791343689

# %% [markdown]
# # Training5 Inference
#
# By looking at the charts, it can be said that training results in overfitting.
#
# A similar architecture was trained with same data in the Training1 notebook file without the Transfer Learning method.
#
# Although the results are much better than those in the Training1 notebook file, a success of about 62% on the Validation data and about 100% on the Training data indicates overfitting.
#
# In this case, it can be said that overfitting is caused by too few images for each person.
#
# This example clearly demonstrates the power of Transfer Learning.
#
# Performance can be improved by trying Hyperparameter Optimization methods.
#
# See https://en.wikipedia.org/wiki/Hyperparameter_optimization.
